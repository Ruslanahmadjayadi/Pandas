# %% [markdown]
# # Plotting Dari Pandas Data Frame

# %% [markdown]
# ## Import Modules
# - Import modules dan menampilkan versi modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %% [markdown]
# ## Mempersiapkan Data Frame

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1,20,size=(n_rows,n_cols)),columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %% [markdown]
# ## Line Plot
# - `df.plot(kind='line')` Untuk memvisualisasikan data dengan Line Plot
# - `df[['A','B']].plot(kind='line')` Untuk menampilkan data di kolom A dan B saja.

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar Plot
# - `df.plot(kind='bar')` Untuk memvisualisasikan data dengan Bar Plot
# - `df[['A','B']].head().plot(kind='bar')` Untuk menampilkan data di kolom A dan B pada 5 baris pertama.
# - `df[['A','B']].head().plot(kind='barh')` Untuk memvisualisasikan data dengan Bar Plot secara horizontal

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Area Plot
# - `df.plot(kind='area')` Untuk memvisualisasikan data dengan Area Plot
# - `df[['A','B']].plot(kind='area')` Untuk menampilkan data di kolom A dan B.
# - `df[['A','B']].head().plot(kind='area')` Untuk menampilkan data di kolom A dan B pada 5 baris pertama saja.

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Box Plot
# - `df.plot(kind='box')`  Untuk memvisualisasikan data dengan Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histogram
# - `df.plot(kind='hist')` Untuk memvisualisasikan data dengan Histogram
# - `df[['A','B']].plot(kind='hist')` Untuk menampilkan data di kolom A dan B.

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['A','B']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Kernel Density Estimation (KDE)
# - `df.plot(kind='kde')` Untuk memvisualisasikan data dengan KDE

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Scatter Plot
# - Scatter plot merupakan visualisasi yang sangat cocok untuk melihat korelasi antara 2 variabel atau antar 2 kolom dalam suatu data frame.
# - `df.plot(x='A',y='B',kind='scatter')` untuk mengspesifikasikan kolom mana saja yang mau diperhatikan dan diharuskan 2 kolom. Karena akan mengamati dua kolom/variabel.

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   4  16   3  18
# 1   3   8   7   5   8
# 2  13   8  13  16   8
# 3   9   4  16  17  18
# 4   8  18   1  10   7

# %%
df.plot(x='A',y='B',kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
